# %% [markdown]
# # DS2002 · Midterm Presentations Run of Show
#
# **Lecture — 2026-11-02 · Fall 2026**
#
# **Time budget:** ~45 minutes
#
# Monday concept + live demo. Follow along; the *your turn* cells are optional participation.
#
# ---

# %% [markdown]
# ## Midterm Presentations — Run of Show
#
# Each team: **6 minutes** + 2 min Q&A. Structure:
#
# 1. The mess (30s) — what was wrong with the data
# 2. The pipeline (1m) — how you cleaned + joined
# 3. Findings (3m) — answers to Q1–Q5, best charts
# 4. Recommendation (1m) — the board-games call
# 5. What broke (30s)
#
# Presentation order and a self-check rubric below.

# %%
checklist = {'runs_top_to_bottom': False, 'six_plots': False, 'weather_api_shown': False,
             'reflection_done': False, 'readme_committed': False}
print('presentation ready:', all(checklist.values()))
