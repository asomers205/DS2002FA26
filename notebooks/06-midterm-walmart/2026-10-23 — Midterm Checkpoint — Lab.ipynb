# %% [markdown]
# # DS2002 · Midterm Checkpoint
#
# **Lab — 2026-10-23 · Fall 2026**
#
# Friday hands-on lab. **This is your graded weekly work.** Complete every TODO on your own.
#
# ---

# %% [markdown]
# ## Lab 09 — Midterm Checkpoint (Week 1 of project)
#
# Graded checkpoint. As a team, submit progress evidence in this notebook.

# %% [markdown]
# ### TODO 1 — paste your cleaning pipeline so far (dedup, SKU fix, timestamp fix)

# %%
# TODO

# %% [markdown]
# ### TODO 2 — show one working weather API call and the parsed DataFrame

# %%
# TODO

# %% [markdown]
# ### TODO 3 — one early chart (daily order volume)

# %%
# TODO

# %% [markdown]
# ### TODO 4 — checklist

# %%
progress = {'clean_pipeline_started': False, 'weather_api_working': False, 'first_chart': False, 'repo_pushed': False}
print('checkpoint ready:', all(progress.values()))

# %% [markdown]
# ### Write-up
#
# What's your biggest risk for the next two weeks, and your plan for it?

# %% [markdown]
# _your answer here_
