# %% [markdown]
# # DS2002 · Midterm Kickoff and Team Formation
#
# **Lecture — 2026-10-19 · Fall 2026**
#
# **Time budget:** ~45 minutes
#
# Monday concept + live demo. Follow along; the *your turn* cells are optional participation.
#
# ---

# %% [markdown]
# ## Midterm Kickoff — Walmart Hurricane Analytics
#
# Full brief: `DS2002_Midterm_Project_Brief.md` in this folder. Read `Walmart Case.pdf` first.
#
# **What you're building (3 weeks, teams of 2–4):** an ETL + analysis notebook on messy Walmart data with a real weather-API join, answering 5 questions.
#
# ### Today
# 1. Form teams (2–4)
# 2. Skim the 5 questions
# 3. Load the data and look at the mess
# 4. Assign week-1 roles

# %% [markdown]
# ### Load the real data and eyeball it

# %%
import pandas as pd
try:
    tx = pd.read_csv('data/walmart_transactions.csv')
    print(tx.shape)
    print(tx.dtypes)
    display(tx.head())
except FileNotFoundError:
    print('Upload the data/ folder in Kaggle/Colab, or run locally in the repo.')

# %% [markdown]
# ### Team charter
#
# Fill this in with your team and commit it.

# %%
team = {
    'name': 'TODO',
    'members': ['TODO', 'TODO'],
    'roles': {'cleaning': 'TODO', 'weather_api': 'TODO', 'analysis': 'TODO', 'viz': 'TODO'},
    'repo_url': 'TODO',
}
team
