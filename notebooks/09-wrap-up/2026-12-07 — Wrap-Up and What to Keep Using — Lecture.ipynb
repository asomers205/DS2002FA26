# %% [markdown]
# # DS2002 · Wrap-Up and What to Keep Using
#
# **Lecture — 2026-12-07 · Fall 2026**
#
# **Time budget:** ~45 minutes
#
# Monday concept + live demo. Follow along; the *your turn* cells are optional participation.
#
# ---

# %% [markdown]
# ## Wrap-Up — What to Keep Using
#
# You built real data pipelines this semester: SQL, Pandas, JSON, APIs, ETL, cleaning, visualization, and two full projects — all in notebooks, all versioned in Git.
#
# ### The transferable loop
# ```
# extract -> clean -> transform -> analyze -> communicate
# ```
#
# ### Keep using
# - Notebooks + Git for any analysis
# - `try/except` + `raise_for_status` on every API
# - A cleaning checklist: dupes, types, missing, text normalization, ID consolidation
# - Charts that state a message, not a topic

# %% [markdown]
# ### Capstone due + presentations today
#
# Final submissions: notebook + README + reflection, pushed to GitHub and linked in Canvas.

# %% [markdown]
# ### One-question retro
#
# What's the one technique from this course you'll use next?

# %% [markdown]
# _your answer here_
