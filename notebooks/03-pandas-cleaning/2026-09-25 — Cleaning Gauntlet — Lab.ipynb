# %% [markdown]
# # DS2002 · Cleaning Gauntlet
#
# **Lab — 2026-09-25 · Fall 2026**
#
# Friday hands-on lab. **This is your graded weekly work.** Complete every TODO on your own.
#
# ---

# %% [markdown]
# ## Lab 05 — Cleaning Gauntlet
#
# A bigger messy frame. Produce a fully clean DataFrame and prove it with assertions.

# %%
import pandas as pd, numpy as np
from io import StringIO
rng = np.random.default_rng(5)
items = ['Cheeseburger','cheese burger','Foam Finger','foam finger','Rain Poncho','rain poncho']
cats = ['Food','food','Merch','Apparel','RainGear','rain-gear']
rows = []
for i in range(300):
    rows.append({
        'order_id': i,
        'item': rng.choice(items),
        'category': rng.choice(cats),
        'qty': rng.choice([1,2,3,-1,np.nan], p=[.5,.25,.15,.05,.05]),
        'price': rng.choice(['$7.50','7.5','$12.00','24','6.0']),
    })
df = pd.DataFrame(rows)
df = pd.concat([df, df.sample(15, random_state=1)])  # inject dupes
df.head()

# %% [markdown]
# ### TODO 1 — drop duplicates

# %%
# TODO

# %% [markdown]
# ### TODO 2 — clean `price` -> float

# %%
# TODO

# %% [markdown]
# ### TODO 3 — `qty` -> numeric, drop rows with missing/negative qty

# %%
# TODO

# %% [markdown]
# ### TODO 4 — canonicalize `item` (map spelling variants to one canonical name)

# %%
# TODO: build a mapping dict and apply it

# %% [markdown]
# ### TODO 5 — normalize `category`

# %%
# TODO

# %% [markdown]
# ### TODO 6 — prove it's clean

# %%
# TODO uncomment once clean:
# assert df.duplicated().sum() == 0
# assert df['qty'].min() >= 1
# assert df['price'].dtype == float
# print('clean:', df.shape)

# %% [markdown]
# ### Write-up
#
# Which cleaning step changed your totals the most? Show the before/after number.

# %% [markdown]
# _your answer here_
