# %% [markdown]
# # DS2002 · Capstone Checkpoint
#
# **Lab — 2026-12-04 · Fall 2026**
#
# Friday hands-on lab. **This is your graded weekly work.** Complete every TODO on your own.
#
# ---

# %% [markdown]
# ## Lab 13 — Capstone Checkpoint (final week before due)
#
# Last graded checkpoint. Evidence that Q1–Q4 are done and Q5 is underway.

# %% [markdown]
# ### TODO 1 — Q1 kickoff surge (chart)

# %%
# TODO

# %% [markdown]
# ### TODO 2 — Q2 item consolidation (before/after)

# %%
# TODO

# %% [markdown]
# ### TODO 3 — Q3 weather-driven demand (API join + chart)

# %%
# TODO

# %% [markdown]
# ### TODO 4 — Q4 zone/distance patterns

# %%
# TODO

# %% [markdown]
# ### TODO 5 — Q5 started: one query against inventory_levels

# %%
# TODO

# %% [markdown]
# ### Write-up
#
# Your current recommendation on ponchos, in one sentence.

# %% [markdown]
# _your answer here_
