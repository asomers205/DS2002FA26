# %% [markdown]
# # DS2002 · Capstone Design and Scoping
#
# **Lecture — 2026-11-16 · Fall 2026**
#
# **Time budget:** ~45 minutes
#
# Monday concept + live demo. Follow along; the *your turn* cells are optional participation.
#
# ---

# %% [markdown]
# ## Capstone — Game Day Pulse: Design & Scoping
#
# Full brief: `DS2002_Capstone_Project_Brief.md`. Teams of 3–4, 4 weeks.
#
# You're the data consultants for the **Cville Game Day Alliance** — vendors around Scott Stadium across the Fall 2026 home weekends. Clean the mess, join weather, and recommend staffing/inventory. This builds directly on the Walmart midterm skills.
#
# ### Today: scope it
# 1. Form teams
# 2. Load the data, look at the mess
# 3. Pick who owns what
# 4. Write a one-paragraph plan

# %%
import pandas as pd
try:
    orders = pd.read_csv('data/gameday_orders.csv')
    print(orders.shape)
    display(orders.head())
    print('\nnulls:\n', orders.isnull().sum())
except FileNotFoundError:
    print('Upload the data/ folder in Kaggle/Colab, or run locally in the repo.')

# %% [markdown]
# ### Spot the mess
#
# List at least 5 data-quality problems you can already see.

# %% [markdown]
# _your list here_
