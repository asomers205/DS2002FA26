# %% [markdown]
# # DS2002 · Capstone Proposal and Pipeline Setup
#
# **Lab — 2026-11-20 · Fall 2026**
#
# Friday hands-on lab. **This is your graded weekly work.** Complete every TODO on your own.
#
# ---

# %% [markdown]
# ## Lab 12 — Capstone Proposal + Pipeline Setup
#
# Graded. Submit your team proposal + evidence the pipeline runs (load -> clean start -> API).

# %% [markdown]
# ### TODO 1 — Proposal: the question you'll emphasize + your recommendation hypothesis

# %% [markdown]
# _proposal here_

# %% [markdown]
# ### TODO 2 — Load all 5 sources (paste code + output)

# %%
# TODO

# %% [markdown]
# ### TODO 3 — Start the cleaning pipeline (at least dedup + price + timestamp)

# %%
# TODO

# %% [markdown]
# ### TODO 4 — One working weather API call, cited

# %%
# TODO

# %% [markdown]
# ### TODO 5 — checklist

# %%
setup = {'all_sources_load': False, 'cleaning_started': False, 'weather_api_working': False, 'repo_pushed': False}
print('setup complete:', all(setup.values()))
