# %% [markdown]
# # DS2002 · Capstone Analysis Clinic
#
# **Lecture — 2026-11-30 · Fall 2026**
#
# **Time budget:** ~45 minutes
#
# Monday concept + live demo. Follow along; the *your turn* cells are optional participation.
#
# ---

# %% [markdown]
# ## Capstone Analysis Clinic
#
# Bring your notebook. Below: the two analyses teams most often get wrong.

# %% [markdown]
# ### Signal vs. artifact (Q5): don't trust a surge until you check inventory

# %%
import pandas as pd, sqlite3
try:
    conn = sqlite3.connect('data/inventory_and_sales.db')
    inv = pd.read_sql_query('SELECT * FROM inventory_levels', conn)
    display(inv.head())
    print(inv.groupby('date')['on_hand'].sum())
except Exception as e:
    print('load the db from data/:', e)

# %% [markdown]
# ### Distance vs. revenue (Q4): join vendors, group by zone, look for outliers

# %%
# pattern: clean_orders.merge(vendors, on='vendor_id').groupby('zone')['revenue'].sum()
print('use your cleaned data here')
