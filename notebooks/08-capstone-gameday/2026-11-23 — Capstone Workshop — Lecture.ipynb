# %% [markdown]
# # DS2002 · Capstone Workshop
#
# **Lecture — 2026-11-23 · Fall 2026**
#
# **Time budget:** ~45 minutes
#
# Monday concept + live demo. Follow along; the *your turn* cells are optional participation.
#
# ---

# %% [markdown]
# ## Capstone Workshop (Mon only — Thanksgiving week)
#
# Working session. No Wednesday/Friday this week. Use today to unblock your team.
#
# ### Sticking points + fixes
# - SKU fragments -> mapping table
# - vendor_id formats -> normalize with regex/replace
# - weather join -> align dates as datetime
# - Q5 -> query `inventory_levels` and cross-check against orders

# %%
import pandas as pd
# vendor_id normalization pattern
s = pd.Series(['V-01','V_01','V01','v-01','V 01'])
norm = s.str.upper().str.replace(r'[^A-Z0-9]', '', regex=True).str.replace(r'^V0*', 'V-', regex=True)
print(list(zip(s, norm)))

# %% [markdown]
# Push your progress before break. Have a good Thanksgiving.
