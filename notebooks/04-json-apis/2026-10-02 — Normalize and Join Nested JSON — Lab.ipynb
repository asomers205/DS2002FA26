# %% [markdown]
# # DS2002 · Normalize and Join Nested JSON
#
# **Lab — 2026-10-02 · Fall 2026**
#
# Friday hands-on lab. **This is your graded weekly work.** Complete every TODO on your own.
#
# ---

# %% [markdown]
# ## Lab 06 — Normalize + Join Nested JSON
#
# You get two JSON blobs. Flatten each, join them, and answer the questions.

# %%
orders_json = [
  {'order':1,'vendor_id':'V-01','lines':[{'item':'Cheeseburger','qty':2},{'item':'Soda','qty':1}]},
  {'order':2,'vendor_id':'V-10','lines':[{'item':'Foam Finger','qty':1}]},
  {'order':3,'vendor_id':'V-01','lines':[{'item':'Hot Dog','qty':3}]},
]
vendors_json = [
  {'vendor_id':'V-01','name':'Hoos Burgers','zone':'A'},
  {'vendor_id':'V-10','name':'Cav Merch','zone':'A'},
]

# %% [markdown]
# ### TODO 1 — explode order lines into one row per item

# %%
import pandas as pd
# TODO: pd.json_normalize(orders_json, record_path='lines', meta=['order','vendor_id'])

# %% [markdown]
# ### TODO 2 — join to vendor names

# %%
# TODO

# %% [markdown]
# ### TODO 3 — total quantity per vendor name

# %%
# TODO

# %% [markdown]
# ### TODO 4 — which zone sold the most items?

# %%
# TODO

# %% [markdown]
# ### Write-up
#
# Why is 'one row per line item' the useful shape here?

# %% [markdown]
# _your answer here_
