# %% [markdown]
# <a href="https://colab.research.google.com/github/asomers205/DS2002FA26/blob/main/notebooks/01-foundations/2026-09-04%20%E2%80%94%20Submission%20Drill%20and%20Fix%20a%20Broken%20Notebook%20%E2%80%94%20Lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # DS2002 · Submission Drill and Fix a Broken Notebook
#
# **Lab — 2026-09-04 · Fall 2026**
#
# ---

# %% [markdown]
# ## Lab 02 — Submission Drill and Fix a Broken Notebook
#
# You have inherited a notebook that does not run. This is the most common way you will meet other people's code, so it is worth practicing deliberately.
#
# Seven cells below are broken. Five throw an error, and two return a wrong answer without complaining at all — those are the dangerous ones. Fix all seven, prove your fixes with assertions, then push through the full submit loop.
#
# **Submit in Canvas:** repository link and notebook link.

# %% [markdown]
# ### How to read an error before you fix it
#
# Python's traceback is read **bottom up**. The last line names the exception and the problem; the line above it points at your code.
#
# ```
# Traceback (most recent call last):
#   File "<stdin>", line 2, in <module>
#     print(greeting)
# NameError: name 'greeting' is not defined
# ```
#
# Four exceptions cover most of what you will hit this semester:
#
# | Exception | Usually means |
# |---|---|
# | `NameError` | The variable was never created, or the cell that created it never ran |
# | `TypeError` | You mixed types — text where a number belongs is the classic |
# | `KeyError` | That column or dictionary key does not exist. Check spelling and case |
# | `FileNotFoundError` | The path is wrong for *this* environment |
#
# For each fix below, write one sentence in the markdown cell saying what was actually wrong. "It works now" is not a diagnosis.

# %% [markdown]
# ### Bug 1 — a name that does not exist

# %%
# TODO: fix so this prints a greeting
greeting = 'hello'

print(greeting)
# Out:
# hello

# %% [markdown]
# **What was wrong:** _..._
#
# greeting variable was not defined so there was nothing that the print statement could refer to

# %% [markdown]
# ### Bug 2 — text where a number belongs
#
# This should print `30`. Note that `'10' + 20` and `'10' + '20'` fail in different ways — make sure you know which one you are looking at.

# %%
# TODO: fix so total is the number 30
total = 10 + 20
print(total)
# Out:
# 30

# %% [markdown]
# **What was wrong:** _..._
#
# the 10 was wrapped in quotes like '10', so it was being treated as a string instead of an integer, once the quotes were removed so it was only 10+20, then we're adding two integers together instead of a string and an integer, which doesn't work

# %% [markdown]
# ### Bug 3 — off the end of a list

# %%
items = ['burger', 'poncho', 'hat', "hat2"]

# TODO: print the LAST item, and do it in a way that still works
#       if someone adds a fourth item tomorrow
print(items[2])

print(items[-1])
# Out:
# hat
# hat2

# %% [markdown]
# **What was wrong:** _..._
#
# it first was using the incorrect value to grab the last item, since we start at 0 when grabbing items from a list or array, it had 3, which technically the third item in items was hat, but since we start at 0, items[2] would get us hat
#
# then, in order to make sure we get the last item in items every time, we can do index -1 in which it reverses the list and grabs the first item in items everytime (in this case now, hat2 as a test)

# %% [markdown]
# ### Bug 4 — no error, wrong answer
#
# This is supposed to be the average. It prints a number, and the number is wrong.

# %%
nums = [2, 4, 6, 8]
average = sum(nums) / len(nums)
print('average:', average)
# Out:
# average: 5.0

# %% [markdown]
# **What was wrong:** _..._
#
# it was using 2 to divide the sum of the numbers in nums, which is we're taking the average we need to divide by the count of all numbers in nums, which we do len(nums) to get

# %% [markdown]
# ### Bug 5 — a table that cannot exist

# %%
import pandas as pd

df = pd.DataFrame({'item': ['a', 'b', 'c'], 'price': [1, 2, 3]})
print(df)
# Out:
#   item  price
# 0    a      1
# 1    b      2
# 2    c      3

# %% [markdown]
# **What was wrong:** _..._
#
# in order to create a df table we need the arrays that are being used to be the same length. in this case, item array had only two values strings: 'a' and 'b' while price has integers" 1, 2, 3
#
# so i added another item to the item array, 'c', and now the table exists and works

# %% [markdown]
# ### Bug 6 — the answer changes when you re-run it
#
# Run the next cell three times and watch the total move. Then fix it using what you built Wednesday: leave the source data alone and derive a new column from it. Your fix must give the same total on every run.

# %%
sales = pd.DataFrame({
    'game': ['NC State', 'Louisville'],
    'units': [1450, 1610],
})

# TODO: rewrite these two lines so re-running cannot change the answer
sales_fee = sales.copy()
sales_fee['units_with_fee'] = sales_fee['units']*1.05

print('total units:', round(sales_fee['units_with_fee'].sum(), 2))
# Out:
# total units: 3213.0

# %%
# Proof — this must print the same number three times
for _ in range(3):

    sales_fee = sales.copy()
    sales_fee['units_with_fee'] = sales_fee['units']*1.05

    print('total units:', round(sales_fee['units_with_fee'].sum(), 2))

    pass
# Out:
# total units: 3213.0
# total units: 3213.0
# total units: 3213.0

# %% [markdown]
# **What was wrong:** _..._
#
# it was grabbing the df and then each unit in sales was being multiplied by 1.05 each time, so it kept recurring over and over as many times as you ran it, so we had to fix it to just grab the values and make a new column that couldn't be run recurringly - or more accurately, the total amount would not change on every run

# %% [markdown]
# ### Bug 7 — a path from someone else's laptop
#
# This notebook was written on a machine you do not have. Fix it with the pattern from Wednesday's studio: look for the file, and fall back to the inline sample so the notebook still runs for whoever opens it next.

# %%
import os
from io import StringIO
import pandas as pd

SAMPLE = '''game,units\nNC State,1450\nLouisville,1610\n'''

def load_csv(orders, fallback_data=SAMPLE):
    if os.path.exists(orders):
        print(f'Using real file: {orders}')
        return pd.read_csv(orders)
    else:
        print(f'Using sample data: {fallback_data.strip()} -- Fallback')
        return pd.read_csv(StringIO(fallback_data))

orders = load_csv('/Users/someone/Desktop/gameday_orders.csv', SAMPLE)
orders
# Out:
# Using sample data: game,units
# NC State,1450
# Louisville,1610 -- Fallback
#          game  units
# 0    NC State   1450
# 1  Louisville   1610

# %% [markdown]
# **What was wrong:** ...
#
# there was no error handling for opening up / running the cell on a machine that does not have access to the file, so we had to add error handling to use the sample file when an error was thrown

# %% [markdown]
# ### Part 8 — prove the fixes
#
# Assertions are how you state what must be true. If one fails, the notebook stops and tells you which claim broke — much better than scrolling for a wrong number.
#
# **TODO:** uncomment each line and make them all pass.

# %%
assert isinstance(greeting, str) and greeting != ''
assert total == 30
assert items[-1] == 'hat2'
assert average == 5
assert len(df) == 2
assert len(orders) >= 2
print('All checks passed.')
# Out:
# All checks passed.

# %% [markdown]
# ### Part 9 — the submit drill
#
# This is the part that is actually being graded on process. Do it in order.
#
# 1. **Restart the kernel and Run All.** Zero errors, top to bottom.
# 2. Download the notebook and put it in your repo under `notebooks/01-foundations/`, named `2026-09-04 — Submission Drill and Fix a Broken Notebook — Lab.ipynb`.
# 3. Commit with a message that says what you did, then push.
# 4. Confirm on github.com that the file is there and opens.
# 5. Fill in the cell below and submit both links in Canvas.
#
# **TODO:** fill in the four values and make the check pass.

# %%
import re

repo_url = 'https://github.com/asomers205/DS2002FA26.git'
commit_sha = '34062f9'
notebook_link = 'https://colab.research.google.com/github/asomers205/DS2002FA26/blob/main/notebooks/01-foundations/2026-09-04%20%E2%80%94%20Submission%20Drill%20and%20Fix%20a%20Broken%20Notebook%20%E2%80%94%20Lab.ipynb'
ran_restart_and_run_all = True   # TODO: set True after you actually do it

checks = {
    'repo URL is a github.com URL':
        repo_url.startswith('https://github.com/')
        and repo_url.count('/') >= 4,
    'commit hash looks like a hash':
        bool(re.fullmatch(r'[0-9a-f]{7,40}', commit_sha.strip())),
    'notebook link filled in':
        notebook_link.startswith('http'),
    'restarted and ran all':
        ran_restart_and_run_all is True,
}

for label, passed in checks.items():
    print('PASS' if passed else 'FAIL', '-', label)

print()
print('Ready to submit:', all(checks.values()))
# Out:
# PASS - repo URL is a github.com URL
# PASS - commit hash looks like a hash
# PASS - notebook link filled in
# PASS - restarted and ran all
#
# Ready to submit: True

# %% [markdown]
# ### Write-up
#
# Bugs 4 and 6 did not raise an error. In a few sentences: how would you catch that class of bug in a project where you do not already know the right answer? Name something concrete you could add to a notebook.

# %% [markdown]
# You could catch the logic error by using a package that already has a formula / function to grab the average instead of having to write the formula yourself, where errors could occur

# %% [markdown]
# ### Stretch
#
# Write a `check_orders(df)` function that raises a clear error if the frame is missing either expected column, has zero rows, or contains a negative value in `units`. Then call it on `orders`. This is the shape of validation you will want in both projects.

# %%
# stretch
def check_orders(df):

    required_columns = ['game', 'units']
    for col in required_columns:
        if col not in df.columns:
            raise ValueError(f"DataFrame is missing required column: '{col}'")

    if df.empty:
        raise ValueError("DataFrame has zero rows.")

    if 'units' in df.columns:
        if not pd.api.types.is_numeric_dtype(df['units']):
            raise ValueError("The 'units' column is not numeric.")
        if (df['units'] < 0).any():
            raise ValueError("DataFrame contains negative values in the 'units' column.")

    print("Orders DataFrame passed all validation checks.")

check_orders(orders)
# Out:
# Orders DataFrame passed all validation checks.
