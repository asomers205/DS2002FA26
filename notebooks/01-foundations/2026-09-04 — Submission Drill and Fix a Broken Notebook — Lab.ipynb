# %% [markdown]
# # DS2002 · Submission Drill and Fix a Broken Notebook
#
# **Lab — 2026-09-04 · Fall 2026**
#
# Friday hands-on lab. **This is your graded weekly work.** Complete every TODO on your own.
#
# ---

# %% [markdown]
# ## Lab 02 — Submission Drill + Fix a Broken Notebook
#
# Every cell below is **broken on purpose**. Fix each one so the notebook runs top-to-bottom with no errors, then push and submit.
#
# This mirrors real life: you inherit code that doesn't run and have to make it work.

# %% [markdown]
# ### Bug 1 — NameError

# %%
# TODO: fix so it prints a greeting
print(greeting)

# %% [markdown]
# ### Bug 2 — TypeError

# %%
# TODO: fix so total is 30
total = '10' + 20
print(total)

# %% [markdown]
# ### Bug 3 — IndexError

# %%
items = ['burger', 'poncho', 'hat']
# TODO: print the LAST item without hardcoding the index
print(items[3])

# %% [markdown]
# ### Bug 4 — Logic bug (wrong answer, no error)
#
# This should compute the average, but it's wrong. Fix it.

# %%
nums = [2, 4, 6, 8]
average = sum(nums) / 2
print('average:', average)

# %% [markdown]
# ### Bug 5 — Broken DataFrame

# %%
import pandas as pd
df = pd.DataFrame({'item': ['a', 'b'], 'price': [1, 2, 3]})  # TODO fix
print(df)

# %% [markdown]
# ### Stretch
#
# Write a one-cell 'smoke test' that asserts all your fixes are correct (use `assert`).

# %%
# stretch
