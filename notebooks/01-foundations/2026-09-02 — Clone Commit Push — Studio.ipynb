# %% [markdown]
# # DS2002 · Clone Commit Push
#
# **Studio — 2026-09-02 · Fall 2026**
#
# **Time budget:** ~45 minutes
#
# Wednesday guided build. We do this together in class — fill in the TODO cells as we go. Each studio ends with a **breakout checkpoint** you submit individually in Canvas.
#
# ---

# %% [markdown]
# ## Studio — Clone / Commit / Push (guided)
#
# We'll practice the submit loop together. Run the Python parts here; do the real `git` parts in a terminal or GitHub's web UI as we go.

# %% [markdown]
# ### 1. The commands (reference)
#
# ```bash
# git clone <url>
# cd ds2002-fa26
# # ... edit files ...
# git add .
# git commit -m "Studio: practice"
# git push
# ```

# %% [markdown]
# ### 2. Build a correctly-named filename
#
# **TODO:** complete `make_filename` to follow the course convention.

# %%
def make_filename(date, topic, kind):
    # TODO: return 'YYYY-MM-DD — Topic — Kind.ipynb'
    pass

print(make_filename('2026-09-02', 'Git Studio', 'Studio'))

# %% [markdown]
# ### 3. Validate a commit message
#
# **TODO:** return True if the message is non-empty and under 60 chars.

# %%
def good_commit(msg):
    # TODO
    pass

print(good_commit('Lab 02: fix broken notebook'))
print(good_commit(''))

# %% [markdown]
# ### 4. Checklist
#
# Run this to self-check before you 'push'.

# %%
checklist = {
    'ran_all_cells': False,   # TODO set True once you Restart+Run All
    'named_correctly': False, # TODO
    'in_right_folder': False, # TODO
}
print('Ready to submit:', all(checklist.values()))

# %% [markdown]
# ---
#
# ## Breakout Checkpoint (Class Participation)
#
# Last ~8 minutes: work in **groups of 4–5**, then complete the cell below **on your own**.
#
# Submit in Canvas (**Studio Checkpoint** for this week) by **Wednesday 11:59pm ET**:
# - Paste the printed output from the cell below, **or**
# - A screenshot of your output
#
# This is an **individual** submission — not one per group.

# %%
# Breakout checkpoint — edit and run before you submit in Canvas
what_worked = "TODO: one result from today's studio"
what_broke = "TODO: one error, question, or 'nothing — it worked'"
print('What worked:', what_worked)
print('What broke / what we tried:', what_broke)
