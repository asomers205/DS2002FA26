# %% [markdown]
# # DS2002 · Environment and GitHub Setup
#
# **Lab — 2026-08-28 · Fall 2026**
#
# Friday hands-on lab. **This is your graded weekly work.** Complete every TODO on your own.
#
# ---

# %% [markdown]
# ## Lab 01 — Environment + GitHub Setup
#
# Goal: prove your whole workflow works end-to-end — run Python in a notebook, and connect a GitHub repo you will use all semester.
#
# **Submit:** your GitHub repo link + this notebook's Kaggle/Colab link in Canvas.

# %% [markdown]
# ### Part 1 — Hello, notebook
#
# **TODO:** set `name` to your name and run the cell.

# %%
name = "TODO: your name"
print(f"Hello, {name}. Welcome to DS2002.")

# %% [markdown]
# ### Part 2 — Python warm-up
#
# **TODO:** build a list of 5 numbers, then print their sum and average *using a loop* (don't use `sum()` for the total — write the loop).

# %%
numbers = []  # TODO: 5 numbers
total = 0
# TODO: loop to accumulate total
average = None  # TODO
print('total:', total, 'average:', average)

# %% [markdown]
# ### Part 3 — A tiny table
#
# **TODO:** make a DataFrame of 3 tailgate items with `item` and `price`, then print the most expensive item.

# %%
import pandas as pd
menu = pd.DataFrame({
    # TODO: fill in item and price columns
})
# TODO: print the row with the max price

# %% [markdown]
# ### Part 4 — GitHub (do this outside the notebook)
#
# 1. Create a repo named `ds2002-fa26` on GitHub.
# 2. Download this notebook (`File -> Download`).
# 3. Put it in a `notebooks/01-foundations/` folder in your repo.
# 4. Commit and push.
#
# **TODO:** paste your repo URL in the string below.

# %%
my_repo_url = "TODO: https://github.com/you/ds2002-fa26"
print(my_repo_url)

# %% [markdown]
# ### Stretch (worth the last points)
#
# Write a function `describe_number(n)` that returns `'even'`/`'odd'` and whether it is negative, and call it on each number from Part 2.

# %%
# stretch
