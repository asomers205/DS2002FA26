# %% [markdown]
# # DS2002 · Visualization Challenge
#
# **Lab — 2026-11-13 · Fall 2026**
#
# Friday hands-on lab. **This is your graded weekly work.** Complete every TODO on your own.
#
# ---

# %% [markdown]
# ## Lab 11 — Visualization Challenge
#
# Build 4 decision-ready charts from the game-day sample. Every chart needs a title that states the *message*, labeled axes with units, and a one-line caption below.

# %%
import pandas as pd, numpy as np
rng = np.random.default_rng(11)
df = pd.DataFrame({
    'hour': rng.integers(9,22,800),
    'zone': rng.choice(['A','B','C'],800,p=[.6,.3,.1]),
    'category': rng.choice(['Food','Merch','RainGear','Drink'],800,p=[.5,.2,.1,.2]),
    'revenue': rng.uniform(3,25,800).round(2),
})
df.head()

# %% [markdown]
# ### Chart 1 — revenue by category (sorted bar)

# %%
# TODO

# %% [markdown]
# ### Chart 2 — revenue by hour (line, mark kickoff at 15.5)

# %%
# TODO

# %% [markdown]
# ### Chart 3 — revenue by zone (bar)

# %%
# TODO

# %% [markdown]
# ### Chart 4 — your choice: a grouped or stacked view that reveals something

# %%
# TODO

# %% [markdown]
# ### Write-up
#
# For each chart, one sentence: what decision does it support?

# %% [markdown]
# _your answer here_
